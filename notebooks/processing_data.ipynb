# %%
import pandas as pd

# %%
df = pd.read_excel('../data/9_CNPM.xls')

# %%
df.head(10)
# Out:
#                     Unnamed: 0                               Unnamed: 1  \
# 0                          NaN                                      NaN
# 1                          NaN                                      NaN
# 2  BẢNG ĐIỂM TỔNG KẾT KHÓA HỌC                                      NaN
# 3                          NaN                                  Lớp:
# 4                          NaN  Ngành: Công nghệ thông tin_DH - 7480201
# 5                          NaN         Chuyên ngành: Công nghệ phần mềm
# 6                          NaN                                      NaN
# 7                          STT                             Mã sinh viên
# 8                          NaN                                      NaN
# 9                            1                               2001181001
#
#        Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5          Unnamed: 6  \
# 0             NaN        NaN        NaN         NaN                 NaN
# ...
