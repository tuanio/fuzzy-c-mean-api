# %%
import pandas as pd

# %%
df = pd.read_excel('../data/9_CNPM.xls')
df
# Out:
#                       Unnamed: 0                                   Unnamed: 1  \
# 0                            NaN                                          NaN
# 1                            NaN                                          NaN
# 2    BẢNG ĐIỂM TỔNG KẾT KHÓA HỌC                                          NaN
# 3                            NaN                                      Lớp:
# 4                            NaN      Ngành: Công nghệ thông tin_DH - 7480201
# ..                           ...                                          ...
# 222                          214                                   2001181435
# 223                          215                                   2001181437
# 224                          216                                   2001181439
# 225                          NaN                                          NaN
# 226                          NaN  In bởi Bùi Thị Nở ngày 25 tháng 11 năm 2020
#
# ...
